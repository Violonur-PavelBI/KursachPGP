# %%
import os
from train import train
import Dataset
from transform import get_ransforms
os.environ["CUDA_VISIBLE_DEVICES"] = "4"

# %%
model_loss, model_acc, overfit_model = train('../belki', 
                                             'train_train.csv',
                                             '../belki', 
                                             'train_val.csv',
                                             Dataset.HPAIC,
                                             N_class = 28,     
                                             transforms = get_ransforms,
                                             zagr = 0,
                                             path = "../snp/5_class_sampler_acc_100-0.7714.tar",
                                             num_epochs=1000,
                                             batch_size = 100,
                                             Name = "HPAIC/HPAIC")

# %%
model_loss, model_acc, overfit_model = train('../belki', 
                                             'train_train.csv',
                                             '../belki', 
                                             'train_val.csv',
                                             Dataset.HPAIC,
                                             N_class = 28,     
                                             transforms = get_ransforms,
                                             zagr = 1,
                                             path = "../snp/HPAIC/HPAIC_acc_977-0.5921.tar",
                                             num_epochs=1000,
                                             batch_size = 100,
                                             Name = "HPAIC/HPAIC+977")
# Out:
# Epoch 1/1000
# ----------
# T_Loss: 1.4563 Acc: 0.6781
# V_Loss: 3.3142 Acc: 0.5919
#
# Epoch 2/1000
# ----------
# T_Loss: 1.4578 Acc: 0.6781
# V_Loss: 3.3177 Acc: 0.5816
#
# Epoch 3/1000
# ----------
# T_Loss: 1.4580 Acc: 0.6759
# V_Loss: 3.3064 Acc: 0.5854
#
# Epoch 4/1000
# ----------
# T_Loss: 1.4574 Acc: 0.6733
# V_Loss: 3.3068 Acc: 0.5893
#
# Epoch 5/1000
# ----------
# T_Loss: 1.4581 Acc: 0.6733
# V_Loss: 3.3119 Acc: 0.5771
#
# Epoch 6/1000
# ----------
# T_Loss: 1.4572 Acc: 0.6800
# V_Loss: 3.3409 Acc: 0.5832
#
# Epoch 7/1000
# ----------
# T_Loss: 1.4565 Acc: 0.6864
# V_Loss: 3.3290 Acc: 0.5892
#
# Epoch 8/1000
# ----------
# T_Loss: 1.4577 Acc: 0.6842
# V_Loss: 3.3304 Acc: 0.5885
#
# Epoch 9/1000
# ----------
# T_Loss: 1.4579 Acc: 0.6745
# V_Loss: 3.3324 Acc: 0.5854
#
# Epoch 10/1000
# ----------
# T_Loss: 1.4570 Acc: 0.6747
# V_Loss: 3.3129 Acc: 0.5867
#
# Epoch 11/1000
# ----------
# T_Loss: 1.4579 Acc: 0.6792
# V_Loss: 3.3363 Acc: 0.5875
#
# Epoch 12/1000
# ----------
# ...
